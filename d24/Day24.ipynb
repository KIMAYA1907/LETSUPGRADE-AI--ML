# %%
import pandas as pd
import numpy as np
df=pd.read_excel("/content/Bank_Personal_Loan_Modelling.xlsx")
df.head()

# %%
df1=df.drop(["ID", "Zipcode"])
df2=df1.dropna()
df3=df2.drop_duplicates()

# %%
from sklearn.ensemble importForestClassifire
df30["CCAVG"]=np.round(df["CCAVG"])

# %%
rf_model=RandomForestClassifire(n_estimators=1000,max_features=2,oob_score=True)
Features=

# %%
rf_model.fit(x=df3[features],y=df3["personal Loan"])
print("ooB Accuracy:")
print(rf_model.ooB_score_);

# %%
for feature,imp in zip(features,rf_model.feature_importances_):
print(feature,imp);

# %%
from sklearn import tree
tree_model=tree.DecisionClassifier()
tree_model=tree.DecisionClassifier(max_depth=6,max_leaf_nodes=10)

# %%
predictors=pd.df([df3["Education"],df3["CCAVG"],df3["INCOME"]]).T

# %%
tree_model.fit(x=predictors,y=df3["personal Loan"])

# %%
with open ("Dtree.dot",'w')as f:
f=tree.export_graphviz(tree_model, feature_names=["Education","CCAVG","INCOME"],out file=f);

# %% [markdown]
# Random forest attrition set

# %%
df4=pd.read_csv("Attrition Rate Analysis.csv")
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
df4["Attrition"]=le.fit_transform(df4["Attrition"])
df4["Bussiness Travel"]=le.fit_transform(df4["Bussiness Travel"])
df4["Department"]=le.fit_transform(df4["Department"])
df4["Educational Field"]=le.fit_transform(df4["Education Field "])
df4["Gender"]=le.fit_transform(df4["Gender"])
df4["Marital status"]=le.fit_transform(df4["Marital status"])
df4["Job Role"]=le.fit_transform(df4["Job Role"])
df4.coloumns
df5=df4.drop(["Employee count","Employee ID","Over18", Standard Hours],axis=1)
df5.coloumns
from sklearn ensamble.import RandomForestClassifiers
df6=df5.dropna()
df7=df6.drop_duplicates()

# %%
rf_model=RandomForestClassifier(n_estimator=1000,max_features=2,ooB_score=True)
Features=[]
