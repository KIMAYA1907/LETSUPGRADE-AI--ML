# %%
c1 = 1 + 2j 
c2 = 2 + 4j 
print('Addition =', c1 + c2)
print('Subtraction =', c1 - c2)
print('Multiplication =', c1 * c2)
print('Division =', c2 / c1)
 
# We can not do floor division and moduleo in complex no it is showed type errors in op
# Out:
# Addition = (3+6j)
# Subtraction = (-1-2j)
# Multiplication = (-6+8j)
# Division = (2+0j)

# %%
# range function
# The range function return a sequence of number.it start by given range by user and increment by 1
# Range syntax have 3 parameters
# Start:the position to start default value is 0
# stop: required  to position to stop
# step: it is optional incremantation
# default value is 1

# %%
 #question 3
num1 = 100
num2 = 45
sub = num1-num2
print(sub)
mul = num1*num2
print(mul)

# %%
#question 4
l = [55,22,33,44,66,77,88,99,34]
for num in l:
    if num % 2 == 0:
        print(num **2 -2)

# %%
#question 5
lst = [55,20,30,40,50,60,70,80,90,100]
for i in lst:
    c=((i%2)>7)
    print(i)
