# %%
 
import re
 
str ="kimayadeshmukh@gmail.com"
print(str)
m= str.split('@')[1]
print(m)
 
 
 
 def missing_numbers(num_list):
      original_list = [x for x in range(num_list[0], num_list[-1] + 1)]
      num_list = set(num_list)
      return (list(num_list ^ set(original_list)))
 
print(missing_numbers([1,2,3,4,6,7,10]))
print(missing_numbers([10,11,12,14,17]))
 
 mylist = [1,2,3,4,5,5,6,3,6,]
mylist = list(dict.fromkeys(mylist))
print(mylist)

# %%
 lst =['Boolean','exit','tired','tree','unworthy',' separate']
x=sorted(lst)
print(x)

# %%
 
#set
#unordered collection and unisex
#set has no index so you can not access items
#you can access item using for and in
thisset = {"apple", "banana", "cherry"}
 
thisset.clear()
 
print(thisset)
