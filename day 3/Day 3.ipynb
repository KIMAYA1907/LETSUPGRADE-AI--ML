# %%
 
# substraction of complex no
a = 4+5j
b = 2+3j
c = a-b
print (c)

# %%
 
#swap two  numbers without temporary variable
x = 15
y = 30
 
x, y = y, x
print("x =", x)
print("y =", y)

# %%
 
#swap two no with temporary variable
num1 = 100
num2 = 200
 
temp = num1
num1 = num2
num2 = temp
print("swapped number",num1)
print("swapped number",num2)

# %%
 
#convert Fahrenheit to celcius and kelvin
Fahrenheit = 47
celcius = (Fahrenheit - 32)* 5/9
print (celcius, Fahrenheit)
 
kelvin = 273.45 + (Fahrenheit- 32)* 5/9
print (Kelvin, Fahrenheit)

# %%
 
#4th root of number
num = 500
n = 4
print(num**(1/n))

# %%
 
# data types
a = 12
 
b = 3.14
 
c = 3+4j
 
s = "kimaya"
 
L=[11,22,33]
 
T =(88,99.66,444)
 
print (type (a))
print (type (b))
print (type (c))
print (type (s))
print (type (L))
print (type (T))

# %%
 #markdown cell 1 open github 2 login to github 3 new respiratory 4 new folder 5 name the folder as LETSUPGRADE 6 drag the folder from jupyter notebook daywise assignment 7 copy link 8 submit on Google form of letsupgrade
